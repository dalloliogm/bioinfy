# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/competitions/playground-series-s6e2/sample_submission.csv
# /kaggle/input/competitions/playground-series-s6e2/train.csv
# /kaggle/input/competitions/playground-series-s6e2/test.csv

# %%
train = pd.read_csv('/kaggle/input/competitions/playground-series-s6e2/train.csv')
test = pd.read_csv('/kaggle/input/competitions/playground-series-s6e2/test.csv')

# %%
train.head()
# Out:
#    id  Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   0   58    1                4  152          239             0            0
# 1   1   52    1                1  125          325             0            2
# 2   2   56    0                2  160          188             0            2
# 3   3   44    0                3  134          229             0            2
# 4   4   58    1                4  140          234             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     158                1            3.6            2
# 1     171                0            0.0            1
# 2     151                0            0.0            1
# 3     150                0            1.0            2
# 4     125                1            3.8            2
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        2         7      Presence
# 1                        0         3       Absence
# 2                        0         3       Absence
# 3                        0         3       Absence
# 4                        3         3      Presence

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630000 entries, 0 to 629999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       630000 non-null  int64
#  1   Age                      630000 non-null  int64
#  2   Sex                      630000 non-null  int64
#  3   Chest pain type          630000 non-null  int64
#  4   BP                       630000 non-null  int64
#  5   Cholesterol              630000 non-null  int64
#  6   FBS over 120             630000 non-null  int64
#  7   EKG results              630000 non-null  int64
#  8   Max HR                   630000 non-null  int64
#  9   Exercise angina          630000 non-null  int64
#  10  ST depression            630000 non-null  float64
#  11  Slope of ST              630000 non-null  int64
#  12  Number of vessels fluro  630000 non-null  int64
#  13  Thallium                 630000 non-null  int64
#  14  Heart Disease            630000 non-null  object
# dtypes: float64(1), int64(13), object(1)
# memory usage: 72.1+ MB

# %%
train['Heart Disease'] = train['Heart Disease'].map({
    "Absence" : 0,
    "Presence" : 1
})

# %%
df = train.copy()
df1 = test.copy()

# %%
# Feature Engineering
df["Age_BP"] = df["Age"] * df["BP"]
df["Age_Chol"] = df["Age"] * df["Cholesterol"]
df["Chol_BP"] = df["Cholesterol"] * df["BP"]
df["ST_Exercise"] = df["ST depression"] * df["Exercise angina"]
df["HR_Exercise"] = df["Max HR"] * df["Exercise angina"]

## Ratio Features
df["Chol_Age_Ratio"] = df["Cholesterol"] / (df["Age"] + 1)
df["BP_Age_Ratio"] = df["BP"] / (df["Age"] + 1)
df["HR_Age_Ratio"] = df["Max HR"] / (df["Age"] + 1)

# Binning
df["Age_Group"] = pd.cut(df["Age"],
                         bins=[0, 40, 55, 65, 100],
                         labels=[0,1,2,3]).astype(int)

df["Chol_Level"] = pd.cut(df["Cholesterol"],
                          bins=[0, 200, 240, 600],
                          labels=[0,1,2]).astype(int)


# Risk Score

df["Risk_Score"] = (
    df["Age"] * 0.03 +
    df["Cholesterol"] * 0.002 +
    df["BP"] * 0.01 +
    df["ST depression"] * 2 +
    df["Exercise angina"] * 5
)

# %%
# Feature Engineering
df1["Age_BP"] = df1["Age"] * df1["BP"]
df1["Age_Chol"] = df1["Age"] * df1["Cholesterol"]
df1["Chol_BP"] = df1["Cholesterol"] * df1["BP"]
df1["ST_Exercise"] = df1["ST depression"] * df1["Exercise angina"]
df1["HR_Exercise"] = df1["Max HR"] * df1["Exercise angina"]

# Ratio Features
df1["Chol_Age_Ratio"] = df1["Cholesterol"] / (df1["Age"] + 1)
df1["BP_Age_Ratio"] = df1["BP"] / (df1["Age"] + 1)
df1["HR_Age_Ratio"] = df1["Max HR"] / (df1["Age"] + 1)

# Binning
df1["Age_Group"] = pd.cut(
    df1["Age"],
    bins=[0, 40, 55, 65, 100],
    labels=[0, 1, 2, 3]
).astype(int)

df1["Chol_Level"] = pd.cut(
    df1["Cholesterol"],
    bins=[0, 200, 240, 600],
    labels=[0, 1, 2]
).astype(int)

# Risk Score
df1["Risk_Score"] = (
    df1["Age"] * 0.03 +
    df1["Cholesterol"] * 0.002 +
    df1["BP"] * 0.01 +
    df1["ST depression"] * 2 +
    df1["Exercise angina"] * 5
)

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder,OrdinalEncoder,StandardScaler

# %%
num_pipeline = Pipeline([
    ('imputer',SimpleImputer(strategy = 'median')),
    ('scaler',StandardScaler())
])

cat_pipeline = Pipeline([
    ('ordinal_encoder',OrdinalEncoder()),
    ('imputer',SimpleImputer(strategy = 'most_frequent')),
    ('cat_encoder',OneHotEncoder(sparse_output = False))
])

# %%
df.columns
# Out:
# Index(['id', 'Age', 'Sex', 'Chest pain type', 'BP', 'Cholesterol',
#        'FBS over 120', 'EKG results', 'Max HR', 'Exercise angina',
#        'ST depression', 'Slope of ST', 'Number of vessels fluro', 'Thallium',
#        'Heart Disease', 'Age_BP', 'Age_Chol', 'Chol_BP', 'ST_Exercise',
#        'HR_Exercise', 'Chol_Age_Ratio', 'BP_Age_Ratio', 'HR_Age_Ratio',
#        'Age_Group', 'Chol_Level', 'Risk_Score'],
#       dtype='object')

# %%
for col in df.columns:
    if df[col].dtype == bool:
        df[col] = df[col].astype(int)
        df1[col] = df1[col].astype(int)

# %%
def separateColumn(df,include_bool = False):
    if include_bool:
        num_cols = df.select_dtypes(include = ['int64','float64','bool']).columns.tolist()
        cat_cols = df.select_dtypes(exclude = ['int64','float64','bool']).columns.tolist()
    else:
        num_cols = df.select_dtypes(include = ['int64','float64']).columns.tolist()
        cat_cols = df.select_dtypes(exclude = ['int64','float64']).columns.tolist()
    return num_cols,cat_cols

# %%
from sklearn.compose import ColumnTransformer

# %%
X = train.drop('Heart Disease', axis=1)

num_attrib, cat_attrib = separateColumn(X)
del num_attrib[-1]
preprocessPipeline = ColumnTransformer([
    ('num',num_pipeline,num_attrib),
    ('cat',cat_pipeline,cat_attrib)
])

# %%
df.columns.tolist()
# Out:
# ['id',
#  'Age',
#  'Sex',
#  'Chest pain type',
#  'BP',
#  'Cholesterol',
#  'FBS over 120',
#  'EKG results',
#  'Max HR',
#  'Exercise angina',
#  'ST depression',
#  'Slope of ST',
#  'Number of vessels fluro',
#  'Thallium',
#  'Heart Disease',
#  'Age_BP',
#  'Age_Chol',
#  'Chol_BP',
#  'ST_Exercise',
#  'HR_Exercise',
#  'Chol_Age_Ratio',
#  'BP_Age_Ratio',
#  'HR_Age_Ratio',
#  'Age_Group',
#  'Chol_Level',
#  'Risk_Score']

# %%
X_train = preprocessPipeline.fit_transform(df.drop('Heart Disease',axis=1))

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y_train = le.fit_transform(df['Heart Disease'])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
Xtrain,xtest,ytrain,ytest = train_test_split(X_train,y_train,test_size = 0.2,random_state=2026)

# %%
from xgboost import XGBClassifier

model = XGBClassifier(
    n_estimators=500,
    learning_rate=0.05,
    max_depth=4,
    min_child_weight=1,
    subsample=0.8,
    colsample_bytree=0.8,
    gamma=0,
    reg_alpha=0.1,
    reg_lambda=1,
    random_state=42,
    use_label_encoder=False,
    early_stopping_rounds=20, 
    eval_metric='logloss'
)

# %%
model.fit(
    Xtrain, ytrain,
    eval_set=[(xtest, ytest)],
    verbose=True
)
# Out:
# [0]	validation_0-logloss:0.66562
# [1]	validation_0-logloss:0.64433
# [2]	validation_0-logloss:0.62368
# [3]	validation_0-logloss:0.60482
# [4]	validation_0-logloss:0.58773
# [5]	validation_0-logloss:0.57187
# /usr/local/lib/python3.12/dist-packages/xgboost/callback.py:386: UserWarning: [21:29:24] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [6]	validation_0-logloss:0.55737
# [7]	validation_0-logloss:0.54382
# [8]	validation_0-logloss:0.53117
# [9]	validation_0-logloss:0.51931
# [10]	validation_0-logloss:0.50831
# [11]	validation_0-logloss:0.49809
# [12]	validation_0-logloss:0.48863
# [13]	validation_0-logloss:0.47975
# [14]	validation_0-logloss:0.47142
# [15]	validation_0-logloss:0.46384
# [16]	validation_0-logloss:0.45646
# [17]	validation_0-logloss:0.44943
# [18]	validation_0-logloss:0.44296
# [19]	validation_0-logloss:0.43689
# [20]	validation_0-logloss:0.43110
# [21]	validation_0-logloss:0.42560
# [22]	validation_0-logloss:0.42041
# [23]	validation_0-logloss:0.41558
# [24]	validation_0-logloss:0.41096
# [25]	validation_0-logloss:0.40669
# [26]	validation_0-logloss:0.40256
# [27]	validation_0-logloss:0.39873
# [28]	validation_0-logloss:0.39507
# [29]	validation_0-logloss:0.39156
# [30]	validation_0-logloss:0.38825
# [31]	validation_0-logloss:0.38500
# [32]	validation_0-logloss:0.38193
# [33]	validation_0-logloss:0.37905
# [34]	validation_0-logloss:0.37625
# [35]	validation_0-logloss:0.37367
# [36]	validation_0-logloss:0.37120
# [37]	validation_0-logloss:0.36873
# [38]	validation_0-logloss:0.36644
# [39]	validation_0-logloss:0.36432
# [40]	validation_0-logloss:0.36223
# [41]	validation_0-logloss:0.36019
# [42]	validation_0-logloss:0.35828
# [43]	validation_0-logloss:0.35648
# [44]	validation_0-logloss:0.35473
# [45]	validation_0-logloss:0.35304
# [46]	validation_0-logloss:0.35144
# [47]	validation_0-logloss:0.34984
# [48]	validation_0-logloss:0.34837
# [49]	validation_0-logloss:0.34696
# [50]	validation_0-logloss:0.34562
# [51]	validation_0-logloss:0.34434
# [52]	validation_0-logloss:0.34309
# [53]	validation_0-logloss:0.34188
# [54]	validation_0-logloss:0.34074
# [55]	validation_0-logloss:0.33968
# [56]	validation_0-logloss:0.33863
# [57]	validation_0-logloss:0.33761
# [58]	validation_0-logloss:0.33669
# [59]	validation_0-logloss:0.33576
# [60]	validation_0-logloss:0.33486
# [61]	validation_0-logloss:0.33401
# [62]	validation_0-logloss:0.33321
# [63]	validation_0-logloss:0.33247
# [64]	validation_0-logloss:0.33164
# [65]	validation_0-logloss:0.33096
# [66]	validation_0-logloss:0.33018
# [67]	validation_0-logloss:0.32947
# [68]	validation_0-logloss:0.32882
# [69]	validation_0-logloss:0.32814
# [70]	validation_0-logloss:0.32744
# [71]	validation_0-logloss:0.32686
# [72]	validation_0-logloss:0.32628
# [73]	validation_0-logloss:0.32575
# [74]	validation_0-logloss:0.32524
# [75]	validation_0-logloss:0.32470
# [76]	validation_0-logloss:0.32423
# [77]	validation_0-logloss:0.32378
# [78]	validation_0-logloss:0.32328
# [79]	validation_0-logloss:0.32281
# [80]	validation_0-logloss:0.32237
# [81]	validation_0-logloss:0.32200
# [82]	validation_0-logloss:0.32162
# [83]	validation_0-logloss:0.32124
# [84]	validation_0-logloss:0.32086
# [85]	validation_0-logloss:0.32053
# [86]	validation_0-logloss:0.32017
# [87]	validation_0-logloss:0.31983
# [88]	validation_0-logloss:0.31951
# [89]	validation_0-logloss:0.31919
# [90]	validation_0-logloss:0.31888
# [91]	validation_0-logloss:0.31859
# [92]	validation_0-logloss:0.31830
# [93]	validation_0-logloss:0.31802
# [94]	validation_0-logloss:0.31776
# [95]	validation_0-logloss:0.31752
# [96]	validation_0-logloss:0.31726
# [97]	validation_0-logloss:0.31705
# [98]	validation_0-logloss:0.31683
# [99]	validation_0-logloss:0.31661
# [100]	validation_0-logloss:0.31638
# [101]	validation_0-logloss:0.31617
# [102]	validation_0-logloss:0.31595
# [103]	validation_0-logloss:0.31576
# [104]	validation_0-logloss:0.31557
# [105]	validation_0-logloss:0.31538
# [106]	validation_0-logloss:0.31519
# [107]	validation_0-logloss:0.31502
# [108]	validation_0-logloss:0.31486
# [109]	validation_0-logloss:0.31469
# [110]	validation_0-logloss:0.31453
# [111]	validation_0-logloss:0.31438
# [112]	validation_0-logloss:0.31422
# [113]	validation_0-logloss:0.31408
# [114]	validation_0-logloss:0.31394
# [115]	validation_0-logloss:0.31380
# [116]	validation_0-logloss:0.31367
# [117]	validation_0-logloss:0.31354
# [118]	validation_0-logloss:0.31340
# [119]	validation_0-logloss:0.31328
# [120]	validation_0-logloss:0.31316
# [121]	validation_0-logloss:0.31306
# [122]	validation_0-logloss:0.31295
# [123]	validation_0-logloss:0.31282
# [124]	validation_0-logloss:0.31273
# [125]	validation_0-logloss:0.31261
# [126]	validation_0-logloss:0.31253
# [127]	validation_0-logloss:0.31241
# [128]	validation_0-logloss:0.31231
# [129]	validation_0-logloss:0.31222
# [130]	validation_0-logloss:0.31214
# [131]	validation_0-logloss:0.31205
# [132]	validation_0-logloss:0.31197
# [133]	validation_0-logloss:0.31188
# [134]	validation_0-logloss:0.31180
# [135]	validation_0-logloss:0.31172
# [136]	validation_0-logloss:0.31164
# [137]	validation_0-logloss:0.31158
# [138]	validation_0-logloss:0.31151
# [139]	validation_0-logloss:0.31144
# [140]	validation_0-logloss:0.31137
# [141]	validation_0-logloss:0.31129
# [142]	validation_0-logloss:0.31122
# [143]	validation_0-logloss:0.31115
# [144]	validation_0-logloss:0.31104
# [145]	validation_0-logloss:0.31097
# [146]	validation_0-logloss:0.31092
# [147]	validation_0-logloss:0.31086
# [148]	validation_0-logloss:0.31081
# [149]	validation_0-logloss:0.31075
# [150]	validation_0-logloss:0.31070
# [151]	validation_0-logloss:0.31065
# [152]	validation_0-logloss:0.31061
# [153]	validation_0-logloss:0.31056
# [154]	validation_0-logloss:0.31051
# [155]	validation_0-logloss:0.31043
# [156]	validation_0-logloss:0.31037
# [157]	validation_0-logloss:0.31033
# [158]	validation_0-logloss:0.31029
# [159]	validation_0-logloss:0.31025
# [160]	validation_0-logloss:0.31020
# [161]	validation_0-logloss:0.31015
# [162]	validation_0-logloss:0.31011
# [163]	validation_0-logloss:0.31007
# [164]	validation_0-logloss:0.31003
# [165]	validation_0-logloss:0.30994
# [166]	validation_0-logloss:0.30990
# [167]	validation_0-logloss:0.30987
# [168]	validation_0-logloss:0.30983
# [169]	validation_0-logloss:0.30979
# [170]	validation_0-logloss:0.30976
# [171]	validation_0-logloss:0.30973
# [172]	validation_0-logloss:0.30969
# [173]	validation_0-logloss:0.30967
# [174]	validation_0-logloss:0.30965
# [175]	validation_0-logloss:0.30962
# [176]	validation_0-logloss:0.30950
# [177]	validation_0-logloss:0.30947
# [178]	validation_0-logloss:0.30944
# [179]	validation_0-logloss:0.30940
# [180]	validation_0-logloss:0.30936
# [181]	validation_0-logloss:0.30930
# [182]	validation_0-logloss:0.30928
# [183]	validation_0-logloss:0.30925
# [184]	validation_0-logloss:0.30922
# [185]	validation_0-logloss:0.30919
# [186]	validation_0-logloss:0.30917
# [187]	validation_0-logloss:0.30913
# [188]	validation_0-logloss:0.30911
# [189]	validation_0-logloss:0.30909
# [190]	validation_0-logloss:0.30907
# [191]	validation_0-logloss:0.30904
# [192]	validation_0-logloss:0.30902
# [193]	validation_0-logloss:0.30900
# [194]	validation_0-logloss:0.30897
# [195]	validation_0-logloss:0.30895
# [196]	validation_0-logloss:0.30893
# [197]	validation_0-logloss:0.30892
# [198]	validation_0-logloss:0.30889
# [199]	validation_0-logloss:0.30888
# [200]	validation_0-logloss:0.30885
# [201]	validation_0-logloss:0.30882
# [202]	validation_0-logloss:0.30880
# [203]	validation_0-logloss:0.30878
# [204]	validation_0-logloss:0.30877
# [205]	validation_0-logloss:0.30871
# [206]	validation_0-logloss:0.30869
# [207]	validation_0-logloss:0.30868
# [208]	validation_0-logloss:0.30865
# [209]	validation_0-logloss:0.30856
# [210]	validation_0-logloss:0.30854
# [211]	validation_0-logloss:0.30852
# [212]	validation_0-logloss:0.30851
# [213]	validation_0-logloss:0.30850
# [214]	validation_0-logloss:0.30849
# [215]	validation_0-logloss:0.30847
# [216]	validation_0-logloss:0.30845
# [217]	validation_0-logloss:0.30844
# [218]	validation_0-logloss:0.30843
# [219]	validation_0-logloss:0.30841
# [220]	validation_0-logloss:0.30839
# [221]	validation_0-logloss:0.30839
# [222]	validation_0-logloss:0.30836
# [223]	validation_0-logloss:0.30834
# [224]	validation_0-logloss:0.30832
# [225]	validation_0-logloss:0.30831
# [226]	validation_0-logloss:0.30831
# [227]	validation_0-logloss:0.30829
# [228]	validation_0-logloss:0.30826
# [229]	validation_0-logloss:0.30825
# [230]	validation_0-logloss:0.30824
# [231]	validation_0-logloss:0.30823
# [232]	validation_0-logloss:0.30822
# [233]	validation_0-logloss:0.30820
# [234]	validation_0-logloss:0.30818
# [235]	validation_0-logloss:0.30817
# [236]	validation_0-logloss:0.30817
# [237]	validation_0-logloss:0.30810
# [238]	validation_0-logloss:0.30808
# [239]	validation_0-logloss:0.30806
# [240]	validation_0-logloss:0.30799
# [241]	validation_0-logloss:0.30798
# [242]	validation_0-logloss:0.30796
# [243]	validation_0-logloss:0.30795
# [244]	validation_0-logloss:0.30789
# [245]	validation_0-logloss:0.30789
# [246]	validation_0-logloss:0.30780
# [247]	validation_0-logloss:0.30779
# [248]	validation_0-logloss:0.30777
# [249]	validation_0-logloss:0.30775
# [250]	validation_0-logloss:0.30769
# [251]	validation_0-logloss:0.30768
# [252]	validation_0-logloss:0.30766
# [253]	validation_0-logloss:0.30765
# [254]	validation_0-logloss:0.30762
# [255]	validation_0-logloss:0.30761
# [256]	validation_0-logloss:0.30760
# [257]	validation_0-logloss:0.30759
# [258]	validation_0-logloss:0.30758
# [259]	validation_0-logloss:0.30758
# [260]	validation_0-logloss:0.30756
# [261]	validation_0-logloss:0.30755
# [262]	validation_0-logloss:0.30750
# [263]	validation_0-logloss:0.30749
# [264]	validation_0-logloss:0.30748
# [265]	validation_0-logloss:0.30747
# [266]	validation_0-logloss:0.30746
# [267]	validation_0-logloss:0.30745
# [268]	validation_0-logloss:0.30743
# [269]	validation_0-logloss:0.30742
# [270]	validation_0-logloss:0.30742
# [271]	validation_0-logloss:0.30741
# [272]	validation_0-logloss:0.30738
# [273]	validation_0-logloss:0.30738
# [274]	validation_0-logloss:0.30737
# [275]	validation_0-logloss:0.30734
# [276]	validation_0-logloss:0.30729
# [277]	validation_0-logloss:0.30729
# [278]	validation_0-logloss:0.30728
# [279]	validation_0-logloss:0.30727
# [280]	validation_0-logloss:0.30727
# [281]	validation_0-logloss:0.30726
# [282]	validation_0-logloss:0.30725
# [283]	validation_0-logloss:0.30725
# [284]	validation_0-logloss:0.30724
# [285]	validation_0-logloss:0.30723
# [286]	validation_0-logloss:0.30722
# [287]	validation_0-logloss:0.30722
# [288]	validation_0-logloss:0.30719
# [289]	validation_0-logloss:0.30719
# [290]	validation_0-logloss:0.30715
# [291]	validation_0-logloss:0.30713
# [292]	validation_0-logloss:0.30711
# [293]	validation_0-logloss:0.30710
# [294]	validation_0-logloss:0.30710
# [295]	validation_0-logloss:0.30705
# [296]	validation_0-logloss:0.30705
# [297]	validation_0-logloss:0.30701
# [298]	validation_0-logloss:0.30700
# [299]	validation_0-logloss:0.30700
# [300]	validation_0-logloss:0.30696
# [301]	validation_0-logloss:0.30692
# [302]	validation_0-logloss:0.30692
# [303]	validation_0-logloss:0.30691
# [304]	validation_0-logloss:0.30690
# [305]	validation_0-logloss:0.30689
# [306]	validation_0-logloss:0.30686
# [307]	validation_0-logloss:0.30683
# [308]	validation_0-logloss:0.30682
# [309]	validation_0-logloss:0.30682
# [310]	validation_0-logloss:0.30681
# [311]	validation_0-logloss:0.30679
# [312]	validation_0-logloss:0.30679
# [313]	validation_0-logloss:0.30678
# [314]	validation_0-logloss:0.30678
# [315]	validation_0-logloss:0.30677
# [316]	validation_0-logloss:0.30673
# [317]	validation_0-logloss:0.30672
# [318]	validation_0-logloss:0.30670
# [319]	validation_0-logloss:0.30670
# [320]	validation_0-logloss:0.30669
# [321]	validation_0-logloss:0.30669
# [322]	validation_0-logloss:0.30668
# [323]	validation_0-logloss:0.30667
# [324]	validation_0-logloss:0.30666
# [325]	validation_0-logloss:0.30666
# [326]	validation_0-logloss:0.30665
# [327]	validation_0-logloss:0.30664
# [328]	validation_0-logloss:0.30663
# [329]	validation_0-logloss:0.30663
# [330]	validation_0-logloss:0.30661
# [331]	validation_0-logloss:0.30661
# [332]	validation_0-logloss:0.30661
# [333]	validation_0-logloss:0.30660
# [334]	validation_0-logloss:0.30659
# [335]	validation_0-logloss:0.30659
# [336]	validation_0-logloss:0.30653
# [337]	validation_0-logloss:0.30652
# [338]	validation_0-logloss:0.30651
# [339]	validation_0-logloss:0.30645
# [340]	validation_0-logloss:0.30645
# [341]	validation_0-logloss:0.30644
# [342]	validation_0-logloss:0.30641
# [343]	validation_0-logloss:0.30639
# [344]	validation_0-logloss:0.30639
# [345]	validation_0-logloss:0.30638
# [346]	validation_0-logloss:0.30638
# [347]	validation_0-logloss:0.30637
# [348]	validation_0-logloss:0.30637
# [349]	validation_0-logloss:0.30634
# [350]	validation_0-logloss:0.30634
# [351]	validation_0-logloss:0.30633
# [352]	validation_0-logloss:0.30633
# [353]	validation_0-logloss:0.30633
# [354]	validation_0-logloss:0.30630
# [355]	validation_0-logloss:0.30629
# [356]	validation_0-logloss:0.30627
# [357]	validation_0-logloss:0.30627
# [358]	validation_0-logloss:0.30626
# [359]	validation_0-logloss:0.30626
# [360]	validation_0-logloss:0.30622
# [361]	validation_0-logloss:0.30619
# [362]	validation_0-logloss:0.30617
# [363]	validation_0-logloss:0.30615
# [364]	validation_0-logloss:0.30614
# [365]	validation_0-logloss:0.30614
# [366]	validation_0-logloss:0.30614
# [367]	validation_0-logloss:0.30614
# [368]	validation_0-logloss:0.30612
# [369]	validation_0-logloss:0.30612
# [370]	validation_0-logloss:0.30611
# [371]	validation_0-logloss:0.30608
# [372]	validation_0-logloss:0.30607
# [373]	validation_0-logloss:0.30606
# [374]	validation_0-logloss:0.30605
# [375]	validation_0-logloss:0.30604
# [376]	validation_0-logloss:0.30602
# [377]	validation_0-logloss:0.30601
# [378]	validation_0-logloss:0.30600
# [379]	validation_0-logloss:0.30600
# [380]	validation_0-logloss:0.30599
# [381]	validation_0-logloss:0.30599
# [382]	validation_0-logloss:0.30598
# [383]	validation_0-logloss:0.30598
# [384]	validation_0-logloss:0.30597
# [385]	validation_0-logloss:0.30597
# [386]	validation_0-logloss:0.30596
# [387]	validation_0-logloss:0.30595
# [388]	validation_0-logloss:0.30595
# [389]	validation_0-logloss:0.30595
# [390]	validation_0-logloss:0.30593
# [391]	validation_0-logloss:0.30592
# [392]	validation_0-logloss:0.30588
# [393]	validation_0-logloss:0.30588
# [394]	validation_0-logloss:0.30588
# [395]	validation_0-logloss:0.30586
# [396]	validation_0-logloss:0.30586
# [397]	validation_0-logloss:0.30585
# [398]	validation_0-logloss:0.30582
# [399]	validation_0-logloss:0.30582
# [400]	validation_0-logloss:0.30581
# [401]	validation_0-logloss:0.30581
# [402]	validation_0-logloss:0.30580
# [403]	validation_0-logloss:0.30578
# [404]	validation_0-logloss:0.30578
# [405]	validation_0-logloss:0.30577
# [406]	validation_0-logloss:0.30574
# [407]	validation_0-logloss:0.30574
# [408]	validation_0-logloss:0.30575
# [409]	validation_0-logloss:0.30574
# [410]	validation_0-logloss:0.30574
# [411]	validation_0-logloss:0.30574
# [412]	validation_0-logloss:0.30573
# [413]	validation_0-logloss:0.30573
# [414]	validation_0-logloss:0.30570
# [415]	validation_0-logloss:0.30569
# [416]	validation_0-logloss:0.30568
# [417]	validation_0-logloss:0.30568
# [418]	validation_0-logloss:0.30566
# [419]	validation_0-logloss:0.30566
# [420]	validation_0-logloss:0.30565
# [421]	validation_0-logloss:0.30564
# [422]	validation_0-logloss:0.30563
# [423]	validation_0-logloss:0.30563
# [424]	validation_0-logloss:0.30562
# [425]	validation_0-logloss:0.30563
# [426]	validation_0-logloss:0.30562
# [427]	validation_0-logloss:0.30561
# [428]	validation_0-logloss:0.30561
# [429]	validation_0-logloss:0.30559
# [430]	validation_0-logloss:0.30559
# [431]	validation_0-logloss:0.30557
# [432]	validation_0-logloss:0.30557
# [433]	validation_0-logloss:0.30557
# [434]	validation_0-logloss:0.30557
# [435]	validation_0-logloss:0.30557
# [436]	validation_0-logloss:0.30555
# [437]	validation_0-logloss:0.30555
# [438]	validation_0-logloss:0.30555
# [439]	validation_0-logloss:0.30554
# [440]	validation_0-logloss:0.30554
# [441]	validation_0-logloss:0.30553
# [442]	validation_0-logloss:0.30553
# [443]	validation_0-logloss:0.30553
# [444]	validation_0-logloss:0.30552
# [445]	validation_0-logloss:0.30551
# [446]	validation_0-logloss:0.30551
# [447]	validation_0-logloss:0.30548
# [448]	validation_0-logloss:0.30547
# [449]	validation_0-logloss:0.30547
# [450]	validation_0-logloss:0.30546
# [451]	validation_0-logloss:0.30546
# [452]	validation_0-logloss:0.30544
# [453]	validation_0-logloss:0.30543
# [454]	validation_0-logloss:0.30543
# [455]	validation_0-logloss:0.30543
# [456]	validation_0-logloss:0.30542
# [457]	validation_0-logloss:0.30542
# [458]	validation_0-logloss:0.30542
# [459]	validation_0-logloss:0.30541
# [460]	validation_0-logloss:0.30540
# [461]	validation_0-logloss:0.30539
# [462]	validation_0-logloss:0.30539
# [463]	validation_0-logloss:0.30539
# [464]	validation_0-logloss:0.30538
# [465]	validation_0-logloss:0.30537
# [466]	validation_0-logloss:0.30538
# [467]	validation_0-logloss:0.30537
# [468]	validation_0-logloss:0.30537
# [469]	validation_0-logloss:0.30536
# [470]	validation_0-logloss:0.30535
# [471]	validation_0-logloss:0.30535
# [472]	validation_0-logloss:0.30534
# [473]	validation_0-logloss:0.30533
# [474]	validation_0-logloss:0.30532
# [475]	validation_0-logloss:0.30531
# [476]	validation_0-logloss:0.30530
# [477]	validation_0-logloss:0.30530
# [478]	validation_0-logloss:0.30529
# [479]	validation_0-logloss:0.30529
# [480]	validation_0-logloss:0.30529
# [481]	validation_0-logloss:0.30527
# [482]	validation_0-logloss:0.30527
# [483]	validation_0-logloss:0.30527
# [484]	validation_0-logloss:0.30526
# [485]	validation_0-logloss:0.30526
# [486]	validation_0-logloss:0.30526
# [487]	validation_0-logloss:0.30525
# [488]	validation_0-logloss:0.30524
# [489]	validation_0-logloss:0.30523
# [490]	validation_0-logloss:0.30523
# [491]	validation_0-logloss:0.30523
# [492]	validation_0-logloss:0.30523
# [493]	validation_0-logloss:0.30522
# [494]	validation_0-logloss:0.30521
# [495]	validation_0-logloss:0.30521
# [496]	validation_0-logloss:0.30521
# [497]	validation_0-logloss:0.30521
# [498]	validation_0-logloss:0.30521
# [499]	validation_0-logloss:0.30520
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=20,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=0,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
X_test = preprocessPipeline.fit_transform(df1)

# %%
y_pred2 = model.predict_proba(X_test)

# %%
len(y_pred2)
# Out:
# 270000

# %%
len(test['id'])
# Out:
# 270000

# %%
submission = pd.DataFrame({
    'id': test['id'],
    'Heart Disease': y_pred2[:,1] 
})
submission.to_csv('submission.csv', index=False)
